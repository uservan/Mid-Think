# %%
import os, json

# 你要统计的关键词
KEYWORDS = ["wait", "alternatively", "hmm"]

def parse_result_file(file_stem: str, path: str, suffix: str = ".json", keywords=KEYWORDS):
    file_path = os.path.join(path, file_stem + suffix)
    if not os.path.exists(file_path):
        print(f"Missing: {file_path}")
        return None

    correct = 0
    total = 0
    total_len = 0
    total_keyword_count = 0

    with open(file_path, "r") as f:
        for line in f:
            line = line.strip()
            if not line:
                continue

            data = json.loads(line)

            if data.get("len", 0) < 10:
                continue

            total += 1
            L = int(data.get("len", 0))
            total_len += L

            if data.get("correct", False):
                correct += 1

            text = (data.get("generated_text", "") or "").lower()
            for kw in keywords:
                total_keyword_count += text.count(kw)

    if total == 0:
        return None

    return {
        "acc": correct / total,
        "avg_len": total_len / total,
        "wait_count": total_keyword_count,
        "n": total,
    }


def parse_tag_budget(file_stem: str, model: str):
    if "begin" in file_stem:
        tag = "begin"
    elif "reason" in file_stem:
        tag = "reason"
    elif "less_think" in file_stem:
        tag = "less_think"
    else:
        tag = "standard"

    budget = None
    if "budget" in file_stem:
        try:
            budget = float(file_stem.split("budget")[-1])
        except Exception:
            budget = None

    if "_False__budget1.0" in file_stem:
        budget = 0.0

    return tag, budget


def collect_results_dict(model: str, files, path: str, suffix: str = ".json", keywords=KEYWORDS):
    results = {}
    for file_stem in files:
        metrics = parse_result_file(file_stem, path=path, suffix=suffix, keywords=keywords)
        if metrics is None:
            continue

        tag, budget = parse_tag_budget(file_stem, model=model)

        key = (tag, budget)
        if key in results:
            print(f"[WARN] duplicate key {key} from file {file_stem}. Overwriting.")
        results[key] = metrics

        print(f"{key} -> acc={metrics['acc']:.3f}, avg_len={metrics['avg_len']:.1f}, wait={metrics['wait_count']}  ({file_stem})")

    return results

# %%
import matplotlib.pyplot as plt

def plot_budget_curve_with_formats(
    results_dict,
    y_key="acc",                 # "acc" / "avg_len" / "wait_count"
    title=None,
    xlabel="Reasoning Budget",
    ylabel=None,
    save_path=None,
    dpi=300
):
    ref_key = ("standard", 1.0)
    if ref_key not in results_dict:
        raise KeyError(f"Missing {ref_key} in results_dict (needed for normalization).")
    ref_len = float(results_dict[ref_key]["avg_len"])

    std_points = []
    for (fmt, b), v in results_dict.items():
        if fmt != "standard":
            continue
        b = float(b)
        y = float(v[y_key])

        if b == 0.0:
            x = 0.0
        elif b == 1.0:
            x = 1.0
        else:
            x = float(v["avg_len"]) / ref_len

        std_points.append((x, y, b))

    std_points.sort(key=lambda t: t[0])
    x_std = [t[0] for t in std_points]
    y_std = [t[1] for t in std_points]
    other_points = {}
    for (fmt, b), v in results_dict.items():
        if fmt == "standard":
            continue
        x = float(v["avg_len"]) / ref_len
        y = float(v[y_key])
        other_points.setdefault(fmt, []).append((x, y))

    fig, ax = plt.subplots(figsize=(4.5, 2.3))

    ax.plot(
        x_std, y_std,
        linewidth=2.2,
        marker="o",
        markersize=8.5,         
        label="standard"
    )

    marker_map = {"begin": "D", "reason": "s", "less_think": "^"}
    red_color = "#d62728"

    for fmt, pts in other_points.items():
        xs = [p[0] for p in pts]
        ys = [p[1] for p in pts]
        ax.scatter(
            xs, ys,
            s=120,               
            marker=marker_map.get(fmt, "o"),
            color=red_color,
            edgecolors="black",
            linewidths=1.0,     
            label=fmt,
            zorder=3
        )

    if ylabel is None:
        ylabel = {
            "acc": "Accuracy",
            "avg_len": "Avg. Output Length",
            "wait_count": "Wait Count"
        }.get(y_key, y_key)

    ax.set_xlabel(xlabel, fontsize=12, fontweight="bold")
    ax.set_ylabel(ylabel, fontsize=12, fontweight="bold")
    if title:
        ax.set_title(title, fontsize=12, fontweight="bold")

    ax.tick_params(axis="both", labelsize=11)
    ax.grid(True, linestyle="--", linewidth=0.8, alpha=0.5)
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)

    all_y = list(y_std)
    for pts in other_points.values():
        all_y.extend([p[1] for p in pts])

    y_min, y_max = min(all_y), max(all_y)
    pad = 0.08 * (y_max - y_min) if y_max > y_min else 0.02
    ax.set_ylim(y_min - pad, y_max + pad)

    # ax.legend(fontsize=10, frameon=False, loc="lower right")
    ax.legend(
        fontsize=10,
        frameon=False,
        loc="lower center",
        bbox_to_anchor=(0.5, 0.95),
        ncol=4,
        handletextpad=0.4,
        columnspacing=1.0
    )

    fig.tight_layout()
    if save_path is not None:
        fig.savefig(save_path, bbox_inches="tight", dpi=dpi)

    return fig, ax

# %% [markdown]
# ## MATH500

# %%
# -------------------- usage --------------------
dataset, n, model = 'MATH-500',5,'DeepSeek-R1-Distill-Qwen-7B'
path = os.path.join('/expert/no_think_pure', dataset, str(n))
files = [
    f"{model}_False_begin_budget1.0",
    f"{model}_False_reason_budget1.0",
    f"{model}_False_less_think_budget1.0",
    f"{model}_False__budget1.0",
    f"{model}_True__budget0.1",
    f"{model}_True__budget0.2",
    f"{model}_True__budget0.3",
    f"{model}_True__budget0.4",
    f"{model}_True__budget0.5",
    f"{model}_True__budget0.6",
    f"{model}_True__budget1.0",
]

results_dict = collect_results_dict(model, files, path=path)
# results_dict[(tag, budget)] => {"acc":..., "avg_len":..., "wait_count":..., "n":...}
fig, ax = plot_budget_curve_with_formats(
    results_dict,
    y_key="acc",
    title=None,
    save_path=f'./budget2/{dataset}-{n}-{model}.pdf'
)
plt.show()
# Out:
# ('begin', 1.0) -> acc=0.752, avg_len=1399.9, wait=7692  (DeepSeek-R1-Distill-Qwen-7B_False_begin_budget1.0)
# ('reason', 1.0) -> acc=0.788, avg_len=1332.0, wait=6790  (DeepSeek-R1-Distill-Qwen-7B_False_reason_budget1.0)
# ('less_think', 1.0) -> acc=0.804, avg_len=1727.7, wait=10988  (DeepSeek-R1-Distill-Qwen-7B_False_less_think_budget1.0)
# ('standard', 0.0) -> acc=0.763, avg_len=728.0, wait=620  (DeepSeek-R1-Distill-Qwen-7B_False__budget1.0)
# ('standard', 0.1) -> acc=0.836, avg_len=2044.5, wait=25758  (DeepSeek-R1-Distill-Qwen-7B_True__budget0.1)
# ('standard', 0.2) -> acc=0.853, avg_len=2452.0, wait=34688  (DeepSeek-R1-Distill-Qwen-7B_True__budget0.2)
# ('standard', 0.3) -> acc=0.867, avg_len=2644.0, wait=39509  (DeepSeek-R1-Distill-Qwen-7B_True__budget0.3)
# ('standard', 0.4) -> acc=0.868, avg_len=2851.2, wait=42119  (DeepSeek-R1-Distill-Qwen-7B_True__budget0.4)
# ('standard', 0.5) -> acc=0.869, avg_len=2954.8, wait=44203  (DeepSeek-R1-Distill-Qwen-7B_True__budget0.5)
# ('standard', 0.6) -> acc=0.872, avg_len=3075.1, wait=49323  (DeepSeek-R1-Distill-Qwen-7B_True__budget0.6)
# ('standard', 1.0) -> acc=0.920, avg_len=3883.0, wait=60430  (DeepSeek-R1-Distill-Qwen-7B_True__budget1.0)

# %% [markdown]
# ## AIME

# %%
# -------------------- usage --------------------
dataset, n, model = 'aimo-validation-aime',5,'DeepSeek-R1-Distill-Qwen-7B'
path = os.path.join('/expert/no_think_pure', dataset, str(n))
files = [
    f"{model}_False_begin_budget1.0",
    f"{model}_False_reason_budget1.0",
    f"{model}_False_less_think_budget1.0",
    f"{model}_False__budget1.0",
    f"{model}_True__budget0.1",
    f"{model}_True__budget0.2",
    f"{model}_True__budget0.3",
    f"{model}_True__budget0.4",
    f"{model}_True__budget0.5",
    f"{model}_True__budget0.6",
    f"{model}_True__budget1.0",
]

results_dict = collect_results_dict(model, files, path=path)
# results_dict[(tag, budget)] => {"acc":..., "avg_len":..., "wait_count":..., "n":...}
fig, ax = plot_budget_curve_with_formats(
    results_dict,
    y_key="acc",
    title=None,
    save_path=f'./budget2/{dataset}-{n}-{model}.pdf'
)
plt.show()
# Out:
# ('begin', 1.0) -> acc=0.262, avg_len=6885.9, wait=10541  (DeepSeek-R1-Distill-Qwen-7B_False_begin_budget1.0)
# ('reason', 1.0) -> acc=0.240, avg_len=5829.6, wait=8107  (DeepSeek-R1-Distill-Qwen-7B_False_reason_budget1.0)
# ('less_think', 1.0) -> acc=0.280, avg_len=8541.5, wait=14982  (DeepSeek-R1-Distill-Qwen-7B_False_less_think_budget1.0)
# ('standard', 0.0) -> acc=0.149, avg_len=2868.4, wait=2015  (DeepSeek-R1-Distill-Qwen-7B_False__budget1.0)
# ('standard', 0.1) -> acc=0.344, avg_len=10379.4, wait=30012  (DeepSeek-R1-Distill-Qwen-7B_True__budget0.1)
# ('standard', 0.2) -> acc=0.384, avg_len=11344.4, wait=34443  (DeepSeek-R1-Distill-Qwen-7B_True__budget0.2)
# ('standard', 0.3) -> acc=0.384, avg_len=11271.0, wait=35367  (DeepSeek-R1-Distill-Qwen-7B_True__budget0.3)
# ('standard', 0.4) -> acc=0.384, avg_len=11630.1, wait=36939  (DeepSeek-R1-Distill-Qwen-7B_True__budget0.4)
# ('standard', 0.5) -> acc=0.396, avg_len=11867.0, wait=38485  (DeepSeek-R1-Distill-Qwen-7B_True__budget0.5)
# ('standard', 0.6) -> acc=0.402, avg_len=12294.6, wait=39861  (DeepSeek-R1-Distill-Qwen-7B_True__budget0.6)
# ('standard', 1.0) -> acc=0.444, avg_len=14529.4, wait=49484  (DeepSeek-R1-Distill-Qwen-7B_True__budget1.0)

# %% [markdown]
# ## GPQA

# %%
# -------------------- usage --------------------
dataset, n, model = 'gpqa',5,'DeepSeek-R1-Distill-Qwen-7B'
path = os.path.join('/expert/no_think_pure', dataset, str(n))
files = [
    f"{model}_False_begin_budget1.0",
    f"{model}_False_reason_budget1.0",
    f"{model}_False_less_think_budget1.0",
    f"{model}_False__budget1.0",
    f"{model}_True__budget0.1",
    f"{model}_True__budget0.2",
    f"{model}_True__budget0.3",
    f"{model}_True__budget0.4",
    f"{model}_True__budget0.5",
    f"{model}_True__budget0.6",
    f"{model}_True__budget1.0",
]

results_dict = collect_results_dict(model, files, path=path)
# results_dict[(tag, budget)] => {"acc":..., "avg_len":..., "wait_count":..., "n":...}
fig, ax = plot_budget_curve_with_formats(
    results_dict,
    y_key="acc",
    title=None,
    save_path=f'./budget2/{dataset}-{n}-{model}.pdf'
)
plt.show()
# Out:
# ('begin', 1.0) -> acc=0.132, avg_len=996.3, wait=1347  (DeepSeek-R1-Distill-Qwen-7B_False_begin_budget1.0)
# ('reason', 1.0) -> acc=0.154, avg_len=863.9, wait=353  (DeepSeek-R1-Distill-Qwen-7B_False_reason_budget1.0)
# ('less_think', 1.0) -> acc=0.174, avg_len=1013.6, wait=900  (DeepSeek-R1-Distill-Qwen-7B_False_less_think_budget1.0)
# ('standard', 0.0) -> acc=0.131, avg_len=605.7, wait=29  (DeepSeek-R1-Distill-Qwen-7B_False__budget1.0)
# ('standard', 0.1) -> acc=0.072, avg_len=1876.2, wait=17484  (DeepSeek-R1-Distill-Qwen-7B_True__budget0.1)
# ('standard', 0.2) -> acc=0.098, avg_len=2471.1, wait=25647  (DeepSeek-R1-Distill-Qwen-7B_True__budget0.2)
# ('standard', 0.3) -> acc=0.111, avg_len=2936.5, wait=30363  (DeepSeek-R1-Distill-Qwen-7B_True__budget0.3)
# ('standard', 0.4) -> acc=0.111, avg_len=3481.0, wait=37026  (DeepSeek-R1-Distill-Qwen-7B_True__budget0.4)
# ('standard', 0.5) -> acc=0.112, avg_len=3947.6, wait=44170  (DeepSeek-R1-Distill-Qwen-7B_True__budget0.5)
# ('standard', 0.6) -> acc=0.121, avg_len=4632.9, wait=51129  (DeepSeek-R1-Distill-Qwen-7B_True__budget0.6)
# ('standard', 1.0) -> acc=0.213, avg_len=7101.1, wait=83315  (DeepSeek-R1-Distill-Qwen-7B_True__budget1.0)
